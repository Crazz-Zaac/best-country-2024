# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('../resources/dataset/best-countries-2024.csv')
df.head()
# Out:
#    population_2024  population_growthRate  land_area        country  \
# 0       1441719852                0.00916    3287590          India
# 1       1425178782               -0.00035    9706961          China
# 2        341814420                0.00535    9372610  United States
# 3        279798049                0.00816    1904569      Indonesia
# 4        245209815                0.01964     881912       Pakistan
#
#           region  unMember  population_density  population_densityMi  \
# 0           Asia      True            484.9067             1255.9084
# 1           Asia      True            151.2174              391.6530
# 2  North America      True             37.3673               96.7813
# 3           Asia      True            149.0254              385.9758
# 4           Asia      True            318.0908              823.8551
#
#                                        share_borders  Hdi2021  Hdi2020  \
# ...

# %%
df.isna().any().any()
# Out:
# True

# %%
any_nan = df.isna().any().any()

if any_nan:
    print("There are NaN values in the DataFrame.")
else:
    print("No NaN values in the DataFrame.")
# Out:
# There are NaN values in the DataFrame.

# %%
clean_df = df.dropna()
clean_df.head(10)
# Out:
#    population_2024  population_growthRate  land_area        country  \
# 0       1441719852                0.00916    3287590          India
# 1       1425178782               -0.00035    9706961          China
# 2        341814420                0.00535    9372610  United States
# 3        279798049                0.00816    1904569      Indonesia
# 4        245209815                0.01964     881912       Pakistan
# 5        229152217                0.02389     923768        Nigeria
# 6        217637297                0.00561    8515767         Brazil
# 7        174701211                0.01010     147570     Bangladesh
# 8        143957079               -0.00337   17098242         Russia
# 9        129719719                0.02523    1104300       Ethiopia
#
#           region  unMember  population_density  population_densityMi  \
# 0           Asia      True            484.9067             1255.9084
# 1           Asia      True            151.2174              391.6530
# ...

# %%
clean_df.isna().any().any()
# Out:
# False

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 129 entries, 0 to 138
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   population_2024        129 non-null    int64
#  1   population_growthRate  129 non-null    float64
#  2   land_area              129 non-null    int64
#  3   country                129 non-null    object
#  4   region                 129 non-null    object
#  5   unMember               129 non-null    bool
#  6   population_density     129 non-null    float64
#  7   population_densityMi   129 non-null    float64
#  8   share_borders          129 non-null    object
#  9   Hdi2021                129 non-null    float64
#  10  Hdi2020                129 non-null    float64
#  11  WorldHappiness2022     129 non-null    float64
# dtypes: bool(1), float64(6), int64(2), object(3)
# memory usage: 12.2+ KB

# %%
clean_df.describe()
# Out:
#        population_2024  population_growthRate     land_area  \
# count     1.290000e+02             129.000000  1.290000e+02
# mean      5.679858e+07               0.009455  8.818932e+05
# std       1.822553e+08               0.012428  2.209874e+06
# min       6.261020e+05              -0.030870  1.104000e+03
# 25%       5.702832e+06               0.001180  6.970000e+04
# 50%       1.256734e+07               0.009160  2.385330e+05
# 75%       4.022173e+07               0.019210  7.526120e+05
# max       1.441720e+09               0.038090  1.709824e+07
#
#        population_density  population_densityMi     Hdi2021     Hdi2020  \
# count          129.000000            129.000000  129.000000  129.000000
# mean           188.025373            486.985713    0.730016    0.730395
# std            641.168605           1660.626680    0.151812    0.150340
# min              2.243100              5.809600    0.394000    0.397000
# ...

# %%
clean_df.head()
# Out:
#    population_2024  population_growthRate  land_area        country  \
# 0       1441719852                0.00916    3287590          India
# 1       1425178782               -0.00035    9706961          China
# 2        341814420                0.00535    9372610  United States
# 3        279798049                0.00816    1904569      Indonesia
# 4        245209815                0.01964     881912       Pakistan
#
#           region  unMember  population_density  population_densityMi  \
# 0           Asia      True            484.9067             1255.9084
# 1           Asia      True            151.2174              391.6530
# 2  North America      True             37.3673               96.7813
# 3           Asia      True            149.0254              385.9758
# 4           Asia      True            318.0908              823.8551
#
#                                        share_borders  Hdi2021  Hdi2020  \
# ...

# %%
asia_df = clean_df[clean_df['region'] == 'Asia']
asia_df.head()
# Out:
#    population_2024  population_growthRate  land_area     country region  \
# 0       1441719852                0.00916    3287590       India   Asia
# 1       1425178782               -0.00035    9706961       China   Asia
# 3        279798049                0.00816    1904569   Indonesia   Asia
# 4        245209815                0.01964     881912    Pakistan   Asia
# 7        174701211                0.01010     147570  Bangladesh   Asia
#
#    unMember  population_density  population_densityMi  \
# 0      True            484.9067             1255.9084
# 1      True            151.2174              391.6530
# 3      True            149.0254              385.9758
# 4      True            318.0908              823.8551
# 7      True           1342.1004             3476.0401
#
#                                        share_borders  Hdi2021  Hdi2020  \
# 0             AFG, BGD, BTN, MMR, CHN, NPL, PAK, LKA    0.633    0.642
# ...

# %%
europe_df = clean_df[clean_df['region'] == 'Europe']
europe_df.head()
# Out:
#     population_2024  population_growthRate  land_area         country  region  \
# 8         143957079               -0.00337   17098242          Russia  Europe
# 16         83252474               -0.00051     357114         Germany  Europe
# 19         67961439                0.00332     242900  United Kingdom  Europe
# 20         64881830                0.00193     551695          France  Europe
# 22         58697744               -0.00294     301336           Italy  Europe
#
#     unMember  population_density  population_densityMi  \
# 8       True              8.7903               22.7668
# 16      True            238.2795              617.1439
# 19      True            280.9136              727.5663
# 20      True            118.4933              306.8976
# 22      True            198.4930              514.0968
#
#                                         share_borders  Hdi2021  Hdi2020  \
# 8   AZE, BLR, CHN, EST, FIN, GEO, KAZ, PRK, LVA, L...    0.829    0.830
# ...

# %%
pop_gt_10m_eu = europe_df[europe_df['population_2024'] > 10000000]
pop_lte_10m_eu = europe_df[europe_df['population_2024'] <= 10000000]
len(pop_gt_1m)
# Out:
# 15

# %%
clean_df['region'].unique()
# Out:
# array(['Asia', 'North America', 'Africa', 'South America', 'Europe'],
#       dtype=object)

# %%
north_america_df = clean_df[clean_df['region'] == 'North America']
len(north_america_df)
# Out:
# 10

# %%
south_america_df = clean_df[clean_df['region'] == 'South America']
len(south_america_df)
# Out:
# 9

# %%
africa_df = clean_df[clean_df['region'] == 'Africa']
africa_df['population_2024'].mean()
# Out:
# 33581289.216216214

# %%
pop_gt_35m_africa = africa_df[africa_df['population_2024'] > 30000000]
pop_lte_35m_africa = africa_df[africa_df['population_2024'] <= 30000000]

# %%
clean_df.head()
# Out:
#    population_2024  population_growthRate  land_area        country  \
# 0       1441719852                0.00916    3287590          India
# 1       1425178782               -0.00035    9706961          China
# 2        341814420                0.00535    9372610  United States
# 3        279798049                0.00816    1904569      Indonesia
# 4        245209815                0.01964     881912       Pakistan
#
#           region  unMember  population_density  population_densityMi  \
# 0           Asia      True            484.9067             1255.9084
# 1           Asia      True            151.2174              391.6530
# 2  North America      True             37.3673               96.7813
# 3           Asia      True            149.0254              385.9758
# 4           Asia      True            318.0908              823.8551
#
#                                        share_borders  Hdi2021  Hdi2020  \
# ...

# %%
clean_df[clean_df['unMember'] != True]
# Out:
#     population_2024  population_growthRate  land_area    country region  \
# 89          7496681                0.00068       1104  Hong Kong   Asia
#
#     unMember  population_density  population_densityMi share_borders  Hdi2021  \
# 89     False           7139.6962            18491.8131           CHN    0.952
#
#     Hdi2020  WorldHappiness2022
# 89    0.949               5.425
